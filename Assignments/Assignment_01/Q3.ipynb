# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\Bapurao Anil Kundale\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\Bapurao Anil Kundale\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
# Reading csv file and printing initial sample rows
df = pd.read_csv('products.csv')
df.head()
# Out:
#    product_id    product_name     category  price  quantity
# 0         101  Wireless Mouse  Electronics    599        25
# 1         102        Keyboard  Electronics    799        15
# 2         103       USB Cable  Accessories    199        50
# 3         104        Notebook   Stationery     49       120
# 4         105    Water Bottle         Home    299        40

# %%
df.sample(10)   # print random rows showing variance
# Out:
#    product_id    product_name     category  price  quantity
# 4         105    Water Bottle         Home    299        40
# 9         110      HDMI Cable  Accessories    299        35
# 5         106        Backpack         Bags    899        10
# 6         107             Pen   Stationery     20       300
# 8         109      Coffee Mug         Home    149        60
# 7         108      Headphones  Electronics   1299         8
# 0         101  Wireless Mouse  Electronics    599        25
# 2         103       USB Cable  Accessories    199        50
# 3         104        Notebook   Stationery     49       120
# 1         102        Keyboard  Electronics    799        15

# %%
print(df)
# Out:
#    product_id    product_name     category  price  quantity
# 0         101  Wireless Mouse  Electronics    599        25
# 1         102        Keyboard  Electronics    799        15
# 2         103       USB Cable  Accessories    199        50
# 3         104        Notebook   Stationery     49       120
# 4         105    Water Bottle         Home    299        40
# 5         106        Backpack         Bags    899        10
# 6         107             Pen   Stationery     20       300
# 7         108      Headphones  Electronics   1299         8
# 8         109      Coffee Mug         Home    149        60
# 9         110      HDMI Cable  Accessories    299        35

# %%
#  prints number of rows
df.iloc[:].shape[0]
# Out:
# 10

# %%
# prints no of rows
len(df)
# Out:
# 10

# %%
# d) Total number of products priced above 500
print(df[df['price'] > 500])

print('\ncount of total number of products priced above 500 are: ',len(df[df['price'] > 500]))
# Out:
#    product_id    product_name     category  price  quantity
# 0         101  Wireless Mouse  Electronics    599        25
# 1         102        Keyboard  Electronics    799        15
# 5         106        Backpack         Bags    899        10
# 7         108      Headphones  Electronics   1299         8
#
# count of total number of products priced above 500 are:  4

# %%
# e) Average price of all products
print(f"Average price of all products : {df['price'].mean()}")
# Out:
# Average price of all products : 461.1

# %%
# f) List all products belonging to a specific category (user input)
print(df)
cat = input("Enter category:")
# Out:
#    product_id    product_name     category  price  quantity
# 0         101  Wireless Mouse  Electronics    599        25
# 1         102        Keyboard  Electronics    799        15
# 2         103       USB Cable  Accessories    199        50
# 3         104        Notebook   Stationery     49       120
# 4         105    Water Bottle         Home    299        40
# 5         106        Backpack         Bags    899        10
# 6         107             Pen   Stationery     20       300
# 7         108      Headphones  Electronics   1299         8
# 8         109      Coffee Mug         Home    149        60
# 9         110      HDMI Cable  Accessories    299        35

# %%
print(df[df['category'] == cat])
# Out:
#    product_id    product_name     category  price  quantity
# 0         101  Wireless Mouse  Electronics    599        25
# 1         102        Keyboard  Electronics    799        15
# 7         108      Headphones  Electronics   1299         8

# %%
# g) Total quantity of all items in stock

print(f"Total quantity of all items in stock: {df['quantity'].sum()}")
# Out:
# Total quantity of all items in stock: 663
